# %% [markdown]
# # webcam

# %%
import os
import cv2 
import numpy as np
import pickle
#from keras import models
from PIL import Image

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
smile_cascade = cv2.CascadeClassifier('haarcascade_smile.xml')
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("recognizer2.yml")

'''from keras.models import load_model

model = models.load_model('models/nmodel.h5')'''  # computer dies :(
# Out:
# "from keras.models import load_model\n\nmodel = models.load_model('models/nmodel.h5')"

# %%
names = {}
with open("names_ids2.pickle", "rb") as f:
    names_1 = pickle.load(f)
    names = {value:key for key,value in names_1.items()}

# %%
cap = cv2.VideoCapture(0)
#cap.set(3,450)             video size
#cap.set(4,650)             video size

while True:
    succes, vid= cap.read()
    gray = cv2.cvtColor(vid, cv2.COLOR_BGR2GRAY)
    facesquare = face_cascade.detectMultiScale(gray, 1.1, 7)
    
    
    '''
    im = Image.fromarray(vid, 'RGB')
    im = im.resize((250,250))
    img_array = np.array(im)
    img_array = np.expand_dims(img_array, axis=0)
    prediction = int(model.predict(img_array)[0][0])
    output = { 0:'apple',1:'banana',2:'mixed',3:'orange'}
    print("Predicted :- ",output[np.argmax(prediction)])
    '''
    
    for (x,y,w,h) in facesquare:       # squares where the face should be
        #print(x,y,w,h) 
        si_gray = gray[y:y+h, x:x+w]   # square interest region
        si_color = vid[y:y+h, x:x+w]
        
        ids, pred = recognizer.predict(si_gray)     # prediction model loaded
        
        if pred >= 45:
            print(names[ids])
            name = names[ids]
            cv2.putText(vid, name, (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (230,230,230), 2, cv2.LINE_AA) # vid, id name, begin cords, font, , color, stroke, 
        
        #img_item = "my_image4.png"
        #cv2.imwrite(img_item, si_color)
                                           
        cv2.rectangle(vid, (x,y), (x+w,y+h), (200,0,0), 2) # video, begin cords, end cords, color, line thickness
        
        smiles = smile_cascade.detectMultiScale(si_gray, 1.8, 20)
        for (sx, sy, sw, sh) in smiles: 
            cv2.rectangle(si_color, (sx, sy), (sx + sw, sy + sh), (0, 0, 255), 2)
        
    cv2.imshow('Video',vid)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break

cap.relase()        
cv2.destoyAllWindows()
# Out:
# Alejandro_Toledo
# Alejandro_Toledo
# Angelina_Jolie
# Alejandro_Toledo
# Alejandro_Toledo
# Angelina_Jolie
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Angelina_Jolie
# Alejandro_Toledo
# Alejandro_Toledo
# Angelina_Jolie
# Angelina_Jolie
# Angelina_Jolie
# Alejandro_Toledo
# Alejandro_Toledo
# Angelina_Jolie
# Angelina_Jolie
# Angelina_Jolie
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
# Alejandro_Toledo
